# %% [markdown]
# #### Attention Mechanism (Seq2Seq Architecture)

# %% [markdown]
# Typical Encoder Decoder Architecture

# %% [markdown]
# Here we are using bidirectional LSTM

# %%
# import image module 
# LSTM RNN
from IPython.display import Image  
# get the image 
Image(url="encoder_decoder.png", width=700)
# Out:
# <img src="encoder_decoder.png" width="700"/>

# %%
from IPython.display import Video

# Display the video (replace 'video.mp4' with your video file path)
Video("intution.mp4", embed=True, width=640, height=480)
# Out:
# <video controls  width="640"  height="480">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# https://erdem.pl/2021/05/introduction-to-attention-mechanism
